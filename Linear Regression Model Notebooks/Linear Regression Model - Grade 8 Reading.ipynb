# %%
# Importing libraries.

import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
avg_scores = pd.read_csv('input_data/naep.csv')
poverty_income = pd.read_csv('input_data/poverty_income.csv')
unemploy_crime = pd.read_csv('input_data/unemployment_crime.csv')

# %%
unemploy_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 459 non-null    int64
#  1   state                459 non-null    object
#  2   unemployment_rate    459 non-null    float64
#  3   violent_crime_rate   459 non-null    float64
#  4   property_crime_rate  459 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 18.1+ KB

# %%
merged_df = pd.merge(avg_scores, poverty_income, how = 'left' , left_on =['state', 'year'], right_on=['state', 'year'])
merged_df = pd.merge(merged_df, unemploy_crime, how = 'left' , left_on =['state', 'year'], right_on=['state', 'year'])
merged_df
# Out:
#       year          state   avg_score      subject  grade  poverty_percent  \
# 0     2019        Alabama  268.703899  Mathematics      8             15.6
# 1     2019         Alaska  274.337801  Mathematics      8             10.2
# 2     2019        Arizona  279.932022  Mathematics      8             13.5
# 3     2019       Arkansas  274.363192  Mathematics      8             16.0
# 4     2019     California  275.608909  Mathematics      8             11.8
# ...    ...            ...         ...          ...    ...              ...
# 1831  2003       Virginia  223.340359      Reading      4             10.0
# 1832  2003     Washington  221.096695      Reading      4             11.0
# 1833  2003  West Virginia  219.179525      Reading      4             16.3
# 1834  2003      Wisconsin  220.833428      Reading      4              8.9
# 1835  2003        Wyoming  222.075166      Reading      4             10.8
#
#       median_income  unemployment_rate  violent_crime_rate  \
# 0             51771                3.0              504.67
# 1             77203                5.4              865.05
# 2             62027                4.9              447.12
# 3             49020                3.5              580.84
# 4             80423                4.2              442.07
# ...             ...                ...                 ...
# 1831          50028                4.1              278.20
# 1832          48185                7.4              346.94
# 1833          32967                6.0              255.43
# 1834          46538                5.7              221.11
# 1835          41554                4.3              261.70
#
#       property_crime_rate
# 0                 2622.80
# 1                 2902.52
# 2                 2435.98
# 3                 2847.71
# 4                 2335.78
# ...                   ...
# 1831              2721.54
# 1832              4754.98
# 1833              2339.02
# 1834              2880.45
# 1835              3315.60
#
# [1836 rows x 10 columns]

# %%
read_merged_df = merged_df.loc[(merged_df['subject'] == 'Reading')]
read_8_merged_df = read_merged_df.loc[(merged_df['grade'] == 8)]
read_8_merged_df
# Out:
#       year          state   avg_score  subject  grade  poverty_percent  \
# 918   2019        Alabama  253.398605  Reading      8             15.6
# 919   2019         Alaska  252.385089  Reading      8             10.2
# 920   2019        Arizona  259.480352  Reading      8             13.5
# 921   2019       Arkansas  258.782754  Reading      8             16.0
# 922   2019     California  258.829734  Reading      8             11.8
# ...    ...            ...         ...      ...    ...              ...
# 1372  2003       Virginia  268.004817  Reading      8             10.0
# 1373  2003     Washington  264.494066  Reading      8             11.0
# 1374  2003  West Virginia  259.564238  Reading      8             16.3
# 1375  2003      Wisconsin  266.468618  Reading      8              8.9
# 1376  2003        Wyoming  267.001029  Reading      8             10.8
#
#       median_income  unemployment_rate  violent_crime_rate  \
# 918           51771                3.0              504.67
# 919           77203                5.4              865.05
# 920           62027                4.9              447.12
# 921           49020                3.5              580.84
# 922           80423                4.2              442.07
# ...             ...                ...                 ...
# 1372          50028                4.1              278.20
# 1373          48185                7.4              346.94
# 1374          32967                6.0              255.43
# 1375          46538                5.7              221.11
# 1376          41554                4.3              261.70
#
#       property_crime_rate
# 918               2622.80
# 919               2902.52
# 920               2435.98
# 921               2847.71
# 922               2335.78
# ...                   ...
# 1372              2721.54
# 1373              4754.98
# 1374              2339.02
# 1375              2880.45
# 1376              3315.60
#
# [459 rows x 10 columns]

# %%
read_8_merged_df = read_8_merged_df.drop(columns = 'year')
read_8_merged_df = read_8_merged_df.drop(columns = 'state')
read_8_merged_df = read_8_merged_df.drop(columns = 'subject')
read_8_merged_df = read_8_merged_df.drop(columns = 'grade')
read_8_merged_df = read_8_merged_df.drop(columns = 'violent_crime_rate')
read_8_merged_df = read_8_merged_df.drop(columns = 'property_crime_rate')
read_8_merged_df
# Out:
#        avg_score  poverty_percent  median_income  unemployment_rate
# 918   253.398605             15.6          51771                3.0
# 919   252.385089             10.2          77203                5.4
# 920   259.480352             13.5          62027                4.9
# 921   258.782754             16.0          49020                3.5
# 922   258.829734             11.8          80423                4.2
# ...          ...              ...            ...                ...
# 1372  268.004817             10.0          50028                4.1
# 1373  264.494066             11.0          48185                7.4
# 1374  259.564238             16.3          32967                6.0
# 1375  266.468618              8.9          46538                5.7
# 1376  267.001029             10.8          41554                4.3
#
# [459 rows x 4 columns]

# %%
read_8_merged_df.isnull().sum()
# Out:
# avg_score            0
# poverty_percent      0
# median_income        0
# unemployment_rate    0
# dtype: int64

# %%
read_8_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 459 entries, 918 to 1376
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_score          459 non-null    float64
#  1   poverty_percent    459 non-null    float64
#  2   median_income      459 non-null    int64
#  3   unemployment_rate  459 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 17.9 KB

# %% [markdown]
# ## Linear Regression Testing - Grade 8 Reading

# %%
# Divide the Data into Attributes & Labels

x = read_8_merged_df.drop(columns = 'avg_score') 
y = read_8_merged_df['avg_score'].values

# %%
# Split Data into Training & Test Sets.

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42)

# %%
# Train the Algorithm.

from sklearn.linear_model import LinearRegression  
regression = LinearRegression()  
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict Scores for the Model.

print(x_test) 
y_pred = regression.predict(x_test)
# Out:
#       poverty_percent  median_income  unemployment_rate
# 1042             15.7          51063                5.4
# 948               9.1          85786                3.4
# 1117             11.7          62745                5.7
# 1356              8.9          56356                5.8
# 1072             10.1          70058                7.0
# ...               ...            ...                ...
# 1035             12.1          54843                3.8
# 1152             10.4          67574                9.3
# 1156             12.0          52135                3.5
# 1022             17.4          51473                6.1
# 1264             15.1          43508                5.7
#
# [115 rows x 3 columns]

# %%
# Compare Actual Data vs Predicted Data

score_vs_factors = pd.DataFrame({"Actual Scores": y_test, "Predicted Scores": y_pred})
score_vs_factors
# Out:
#      Actual Scores  Predicted Scores
# 0       264.496755        260.961790
# 1       270.357938        266.488721
# 2       267.589864        265.326181
# 3       267.786953        269.143681
# 4       261.256093        267.318305
# ..             ...               ...
# 110     268.200596        264.639153
# 111     275.183164        267.849064
# 112     268.694218        264.810864
# 113     262.769392        259.086457
# 114     257.421203        262.211437
#
# [115 rows x 2 columns]

# %%
pd.DataFrame(np.c_[x_test,y_test,y_pred], columns=["Poverty Percentage","Median Income", "Unemployment Rate","Actual Scores","Predicted Scores"])
# Out:
#      Poverty Percentage  Median Income  Unemployment Rate  Actual Scores  \
# 0                  15.7        51063.0                5.4     264.496755
# 1                   9.1        85786.0                3.4     270.357938
# 2                  11.7        62745.0                5.7     267.589864
# 3                   8.9        56356.0                5.8     267.786953
# 4                  10.1        70058.0                7.0     261.256093
# ..                  ...            ...                ...            ...
# 110                12.1        54843.0                3.8     268.200596
# 111                10.4        67574.0                9.3     275.183164
# 112                12.0        52135.0                3.5     268.694218
# 113                17.4        51473.0                6.1     262.769392
# 114                15.1        43508.0                5.7     257.421203
#
#      Predicted Scores
# 0          260.961790
# 1          266.488721
# 2          265.326181
# 3          269.143681
# 4          267.318305
# ..                ...
# 110        264.639153
# 111        267.849064
# 112        264.810864
# 113        259.086457
# 114        262.211437
#
# [115 rows x 5 columns]

# %%
# Test with Custom Data.

input = [[15.6, 51771, 3.0]]
prediction = regression.predict(input)
print("Predicted Score = {}".format(prediction[0]))
# Out:
# Predicted Score = 260.2500041125377
# C:\Users\amylb\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Evaluate Performance of Algorithm.

from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 3.777171518438607

# %%
import pickle
# save the model to disk
filename = 'grade_8_read_model.sav'
pickle.dump(regression, open(filename, 'wb'))

# %%
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.34206846577277283

# %%
regression.score(x_train, y_train)
# Out:
# 0.2733295468945729

# %%
regression.score(x_test, y_test)
# Out:
# 0.34206846577277283
