# %%
# Importing libraries.

import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
avg_scores = pd.read_csv('input_data/naep.csv')
poverty_income = pd.read_csv('input_data/poverty_income.csv')
unemploy_crime = pd.read_csv('input_data/unemployment_crime.csv')

# %%
unemploy_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 459 non-null    int64
#  1   state                459 non-null    object
#  2   unemployment_rate    459 non-null    float64
#  3   violent_crime_rate   459 non-null    float64
#  4   property_crime_rate  459 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 18.1+ KB

# %%
merged_df = pd.merge(avg_scores, poverty_income, how = 'left' , left_on =['state', 'year'], right_on=['state', 'year'])
merged_df = pd.merge(merged_df, unemploy_crime, how = 'left' , left_on =['state', 'year'], right_on=['state', 'year'])
merged_df
# Out:
#       year          state   avg_score      subject  grade  poverty_percent  \
# 0     2019        Alabama  268.703899  Mathematics      8             15.6
# 1     2019         Alaska  274.337801  Mathematics      8             10.2
# 2     2019        Arizona  279.932022  Mathematics      8             13.5
# 3     2019       Arkansas  274.363192  Mathematics      8             16.0
# 4     2019     California  275.608909  Mathematics      8             11.8
# ...    ...            ...         ...          ...    ...              ...
# 1831  2003       Virginia  223.340359      Reading      4             10.0
# 1832  2003     Washington  221.096695      Reading      4             11.0
# 1833  2003  West Virginia  219.179525      Reading      4             16.3
# 1834  2003      Wisconsin  220.833428      Reading      4              8.9
# 1835  2003        Wyoming  222.075166      Reading      4             10.8
#
#       median_income  unemployment_rate  violent_crime_rate  \
# 0             51771                3.0              504.67
# 1             77203                5.4              865.05
# 2             62027                4.9              447.12
# 3             49020                3.5              580.84
# 4             80423                4.2              442.07
# ...             ...                ...                 ...
# 1831          50028                4.1              278.20
# 1832          48185                7.4              346.94
# 1833          32967                6.0              255.43
# 1834          46538                5.7              221.11
# 1835          41554                4.3              261.70
#
#       property_crime_rate
# 0                 2622.80
# 1                 2902.52
# 2                 2435.98
# 3                 2847.71
# 4                 2335.78
# ...                   ...
# 1831              2721.54
# 1832              4754.98
# 1833              2339.02
# 1834              2880.45
# 1835              3315.60
#
# [1836 rows x 10 columns]

# %% [markdown]
# ## Neural Network Testing - Grade 4 Reading

# %%
reading_merged_df = merged_df.loc[(merged_df['subject'] == 'Reading')]
read_4_merged_df = reading_merged_df.loc[(merged_df['grade'] == 4)]
read_4_merged_df
# Out:
#       year          state   avg_score  subject  grade  poverty_percent  \
# 1377  2019        Alabama  211.728520  Reading      4             15.6
# 1378  2019         Alaska  204.373572  Reading      4             10.2
# 1379  2019        Arizona  215.841231  Reading      4             13.5
# 1380  2019       Arkansas  215.054222  Reading      4             16.0
# 1381  2019     California  216.481266  Reading      4             11.8
# ...    ...            ...         ...      ...    ...              ...
# 1831  2003       Virginia  223.340359  Reading      4             10.0
# 1832  2003     Washington  221.096695  Reading      4             11.0
# 1833  2003  West Virginia  219.179525  Reading      4             16.3
# 1834  2003      Wisconsin  220.833428  Reading      4              8.9
# 1835  2003        Wyoming  222.075166  Reading      4             10.8
#
#       median_income  unemployment_rate  violent_crime_rate  \
# 1377          51771                3.0              504.67
# 1378          77203                5.4              865.05
# 1379          62027                4.9              447.12
# 1380          49020                3.5              580.84
# 1381          80423                4.2              442.07
# ...             ...                ...                 ...
# 1831          50028                4.1              278.20
# 1832          48185                7.4              346.94
# 1833          32967                6.0              255.43
# 1834          46538                5.7              221.11
# 1835          41554                4.3              261.70
#
#       property_crime_rate
# 1377              2622.80
# 1378              2902.52
# 1379              2435.98
# 1380              2847.71
# 1381              2335.78
# ...                   ...
# 1831              2721.54
# 1832              4754.98
# 1833              2339.02
# 1834              2880.45
# 1835              3315.60
#
# [459 rows x 10 columns]

# %%
read_4_merged_df = read_4_merged_df.drop(columns = 'year')
read_4_merged_df = read_4_merged_df.drop(columns = 'state')
read_4_merged_df = read_4_merged_df.drop(columns = 'subject')
read_4_merged_df = read_4_merged_df.drop(columns = 'grade')
read_4_merged_df = read_4_merged_df.drop(columns = 'violent_crime_rate')
read_4_merged_df = read_4_merged_df.drop(columns = 'property_crime_rate')
read_4_merged_df
# Out:
#        avg_score  poverty_percent  median_income  unemployment_rate
# 1377  211.728520             15.6          51771                3.0
# 1378  204.373572             10.2          77203                5.4
# 1379  215.841231             13.5          62027                4.9
# 1380  215.054222             16.0          49020                3.5
# 1381  216.481266             11.8          80423                4.2
# ...          ...              ...            ...                ...
# 1831  223.340359             10.0          50028                4.1
# 1832  221.096695             11.0          48185                7.4
# 1833  219.179525             16.3          32967                6.0
# 1834  220.833428              8.9          46538                5.7
# 1835  222.075166             10.8          41554                4.3
#
# [459 rows x 4 columns]

# %%
read_4_merged_df.isnull().sum()
# Out:
# avg_score            0
# poverty_percent      0
# median_income        0
# unemployment_rate    0
# dtype: int64

# %%
read_4_merged_df.describe()
# Out:
#         avg_score  poverty_percent  median_income  unemployment_rate
# count  459.000000       459.000000     459.000000         459.000000
# mean   219.999774        13.500000   52867.071895           5.681481
# std      6.656643         3.217603   10893.021072           2.113221
# min    188.374479         6.400000   32397.000000           2.300000
# 25%    216.357610        10.900000   44802.500000           4.100000
# 50%    221.220580        13.100000   51086.000000           5.200000
# 75%    224.478063        15.850000   59447.000000           6.900000
# max    236.773867        23.900000   90395.000000          13.700000

# %%
bins = [0, 195.9, 210.9, 225.9, 240]
group_names = [0, 1, 2, 3]
read_4_merged_df['new_col'] = pd.cut(read_4_merged_df['avg_score'],bins, labels=group_names, include_lowest=True)

# %%
read_4_merged_df = read_4_merged_df.drop(columns = 'avg_score')
read_4_merged_df
# Out:
#       poverty_percent  median_income  unemployment_rate new_col
# 1377             15.6          51771                3.0       2
# 1378             10.2          77203                5.4       1
# 1379             13.5          62027                4.9       2
# 1380             16.0          49020                3.5       2
# 1381             11.8          80423                4.2       2
# ...               ...            ...                ...     ...
# 1831             10.0          50028                4.1       2
# 1832             11.0          48185                7.4       2
# 1833             16.3          32967                6.0       2
# 1834              8.9          46538                5.7       2
# 1835             10.8          41554                4.3       2
#
# [459 rows x 4 columns]

# %%
x = read_4_merged_df.drop(columns = 'new_col').values
y = read_4_merged_df['new_col'].values

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

y = tf.keras.utils.to_categorical(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state = 78)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
input_features = len(x_train_scaled[0])
hidden_layer1 = 50
hidden_layer2 = 35
# hidden_layer3 = 10

nn = tf.keras.models.Sequential()

nn.add(tf.keras.layers.Dense(units = hidden_layer1, input_dim = input_features, activation = 'relu'))

nn.add(tf.keras.layers.Dense(units = hidden_layer2, activation = 'relu'))

# nn.add(tf.keras.layers.Dense(units = hidden_layer3, activation = 'relu'))

nn.add(tf.keras.layers.Dense(units = 4, activation = 'softmax'))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                200
#
#  dense_1 (Dense)             (None, 35)                1785
#
#  dense_2 (Dense)             (None, 4)                 144
#
# =================================================================
# Total params: 2,129
# Trainable params: 2,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="categorical_crossentropy", optimizer= "adam", metrics=['accuracy'])

# %%
fit_model = nn.fit(x_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 3ms/step - loss: 1.4910 - accuracy: 0.2180
# Epoch 2/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3168 - accuracy: 0.4738
# Epoch 3/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1833 - accuracy: 0.6773
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0666 - accuracy: 0.7267
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9653 - accuracy: 0.7267
# Epoch 6/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8827 - accuracy: 0.7267
# Epoch 7/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8284 - accuracy: 0.7267
# Epoch 8/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7937 - accuracy: 0.7267
# Epoch 9/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7683 - accuracy: 0.7267
# Epoch 10/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7453 - accuracy: 0.7267
# Epoch 11/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7250 - accuracy: 0.7355
# Epoch 12/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7089 - accuracy: 0.7355
# Epoch 13/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.7384
# Epoch 14/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.7355
# Epoch 15/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6703 - accuracy: 0.7442
# Epoch 16/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6586 - accuracy: 0.7616
# Epoch 17/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6511 - accuracy: 0.7645
# Epoch 18/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6445 - accuracy: 0.7703
# Epoch 19/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6395 - accuracy: 0.7733
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.7703
# Epoch 21/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6298 - accuracy: 0.7733
# Epoch 22/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6261 - accuracy: 0.7703
# Epoch 23/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6221 - accuracy: 0.7762
# Epoch 24/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6180 - accuracy: 0.7791
# Epoch 25/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6169 - accuracy: 0.7791
# Epoch 26/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.7820
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6121 - accuracy: 0.7791
# Epoch 28/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6104 - accuracy: 0.7820
# Epoch 29/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6063 - accuracy: 0.7878
# Epoch 30/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6053 - accuracy: 0.7791
# Epoch 31/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6057 - accuracy: 0.7791
# Epoch 32/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6013 - accuracy: 0.7849
# Epoch 33/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6002 - accuracy: 0.7936
# Epoch 34/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6009 - accuracy: 0.7878
# Epoch 35/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5975 - accuracy: 0.7878
# Epoch 36/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5988 - accuracy: 0.7820
# Epoch 37/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5966 - accuracy: 0.7791
# Epoch 38/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.7907
# Epoch 39/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5938 - accuracy: 0.7936
# Epoch 40/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.7936
# Epoch 41/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5908 - accuracy: 0.7965
# Epoch 42/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5895 - accuracy: 0.7907
# Epoch 43/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5879 - accuracy: 0.7907
# Epoch 44/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5870 - accuracy: 0.7965
# Epoch 45/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.7936
# Epoch 46/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5851 - accuracy: 0.7936
# Epoch 47/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5845 - accuracy: 0.7965
# Epoch 48/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5830 - accuracy: 0.7965
# Epoch 49/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5813 - accuracy: 0.7936
# Epoch 50/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.7994
# Epoch 51/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5804 - accuracy: 0.7994
# Epoch 52/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5791 - accuracy: 0.7936
# Epoch 53/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5783 - accuracy: 0.7994
# Epoch 54/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.7936
# Epoch 55/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5780 - accuracy: 0.8023
# Epoch 56/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5761 - accuracy: 0.8023
# Epoch 57/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5780 - accuracy: 0.7994
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5745 - accuracy: 0.7994
# Epoch 59/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5751 - accuracy: 0.7994
# Epoch 60/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.7994
# Epoch 61/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5725 - accuracy: 0.7994
# Epoch 62/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5734 - accuracy: 0.7994
# Epoch 63/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5712 - accuracy: 0.8023
# Epoch 64/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5727 - accuracy: 0.7994
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.8023
# Epoch 66/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5694 - accuracy: 0.8023
# Epoch 67/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5716 - accuracy: 0.8023
# Epoch 68/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5704 - accuracy: 0.7994
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5693 - accuracy: 0.7965
# Epoch 70/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5680 - accuracy: 0.8023
# Epoch 71/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5669 - accuracy: 0.8023
# Epoch 72/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7936
# Epoch 73/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5642 - accuracy: 0.8052
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5678 - accuracy: 0.7907
# Epoch 75/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.7936
# Epoch 76/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5622 - accuracy: 0.8081
# Epoch 77/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5640 - accuracy: 0.7965
# Epoch 78/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.7936
# Epoch 79/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5620 - accuracy: 0.8023
# Epoch 80/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5615 - accuracy: 0.8023
# Epoch 81/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5613 - accuracy: 0.8023
# Epoch 82/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.7994
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.8023
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5601 - accuracy: 0.8023
# Epoch 85/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5577 - accuracy: 0.7994
# Epoch 86/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5599 - accuracy: 0.8023
# Epoch 87/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5654 - accuracy: 0.7965
# Epoch 88/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.7994
# Epoch 89/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5577 - accuracy: 0.7965
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5581 - accuracy: 0.8023
# Epoch 91/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.8023
# Epoch 92/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5552 - accuracy: 0.7994
# Epoch 93/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.8023
# Epoch 94/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5537 - accuracy: 0.8023
# Epoch 95/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5548 - accuracy: 0.8052
# Epoch 96/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5543 - accuracy: 0.8052
# Epoch 97/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7994
# Epoch 98/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.7994
# Epoch 99/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5516 - accuracy: 0.8023
# Epoch 100/100
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.8052

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 0.4523 - accuracy: 0.8348 - 260ms/epoch - 65ms/step
# Loss: 0.45225226879119873, Accuracy: 0.834782600402832

# %%
input = [[15.6, 51771, 3.0]]
predictions = nn.predict(input)
print(predictions)
# Out:
# [[0. 0. 1. 0.]]

# %%
# nn.save('grade_4_read_model.h5')
